# %% [markdown]
# # Image classification

# %% [markdown]
# ## Import TensorFlow and other libraries

# %%
#matplotlib is used to transforman data and plot it visually.
import matplotlib.pyplot as plt

#numpy is a math library for handling mathy matricies
import numpy as np

#os is used for accessing the local computer system
import os

#image library used to handle images
import PIL

#opencv library is great for computer vision, we use it to easily access webcameras
import cv2

#libraries for ev3dev robot
import rpyc
#conn = rpyc.classic.connect('169.254.214.206')

#handy libraries
import time
import random

#tensorflow is our machine learning library that provides a way to create, edit, save, load our models.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# ##### Show Tensorflow version

# %%
print(tf.__version__)
# Out:
# 2.4.1

# %% [markdown]
# ## Create a dataset

# %% [markdown]
# Define some parameters for the loader:

# %%
data_dir = "C:/Users/MLSE IT HELPDESK/Desktop/OMARADEV/AI/EC_DATASET"
batch_size = 16
img_height = 64
img_width = 64

# %% [markdown]
# 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=1,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3803 files belonging to 5 classes.
# Using 3043 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=1,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3803 files belonging to 5 classes.
# Using 760 files for validation.

# %% [markdown]
# ## Our Dataset is made up of

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['CAPACITOR', 'IC', 'POTENTIOMETER', 'RESISTOR', 'SCREW']

# %% [markdown]
# ## Visualize the data
#
# Here are 9 images from the training dataset.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("on")

# %% [markdown]
# ## Configure the dataset for performance
#
# Let's make sure to use buffered prefetching so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data.
#
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the [data performance guide](https://www.tensorflow.org/guide/data_performance#prefetching).

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical", input_shape=(img_height, img_width, 3)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
    layers.experimental.preprocessing.RandomTranslation(0.20,0.20),
  ]
)

# %% [markdown]
# Data augementation examples

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will use data augmentation to train a model in a moment.

# %%
num_classes = 5
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.1),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.1),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 64, 64, 3)         0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 16)        448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 548,645
# Trainable params: 548,645
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 80
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/80
# 191/191 [==============================] - 61s 262ms/step - loss: 1.4898 - accuracy: 0.3369 - val_loss: 1.0880 - val_accuracy: 0.5461  - ETA: 2
# Epoch 2/80
# 191/191 [==============================] - 34s 179ms/step - loss: 0.9760 - accuracy: 0.6034 - val_loss: 1.2421 - val_accuracy: 0.5434s - loss: 0.9812 - accuracy: 0.60 - ETA: 1s - loss: 0.980
# Epoch 3/80
# 191/191 [==============================] - 29s 150ms/step - loss: 0.7133 - accuracy: 0.7018 - val_loss: 0.8268 - val_accuracy: 0.6697
# Epoch 4/80
# 191/191 [==============================] - 25s 132ms/step - loss: 0.5515 - accuracy: 0.7914 - val_loss: 0.5862 - val_accuracy: 0.7513
# Epoch 5/80
# 191/191 [==============================] - 18s 94ms/step - loss: 0.4823 - accuracy: 0.8221 - val_loss: 0.6863 - val_accuracy: 0.7395
# Epoch 6/80
# 191/191 [==============================] - 19s 102ms/step - loss: 0.4034 - accuracy: 0.8446 - val_loss: 0.8038 - val_accuracy: 0.7684
# Epoch 7/80
# 191/191 [==============================] - 19s 101ms/step - loss: 0.3243 - accuracy: 0.8830 - val_loss: 1.4099 - val_accuracy: 0.6421
# Epoch 8/80
# 191/191 [==============================] - 19s 100ms/step - loss: 0.2715 - accuracy: 0.9047 - val_loss: 0.9437 - val_accuracy: 0.7500
# Epoch 9/80
# 191/191 [==============================] - 19s 98ms/step - loss: 0.2984 - accuracy: 0.8798 - val_loss: 0.8591 - val_accuracy: 0.7724
# Epoch 10/80
# 191/191 [==============================] - 20s 103ms/step - loss: 0.2253 - accuracy: 0.9169 - val_loss: 0.7009 - val_accuracy: 0.8145
# Epoch 11/80
# 191/191 [==============================] - 19s 97ms/step - loss: 0.2348 - accuracy: 0.9064 - val_loss: 0.7344 - val_accuracy: 0.8013
# Epoch 12/80
# 191/191 [==============================] - 19s 98ms/step - loss: 0.2217 - accuracy: 0.9203 - val_loss: 0.9664 - val_accuracy: 0.7855
# Epoch 13/80
# 191/191 [==============================] - 18s 97ms/step - loss: 0.2096 - accuracy: 0.9262 - val_loss: 0.3991 - val_accuracy: 0.8618
# Epoch 14/80
# 191/191 [==============================] - 20s 103ms/step - loss: 0.2621 - accuracy: 0.9034 - val_loss: 0.7921 - val_accuracy: 0.8105
# Epoch 15/80
# 191/191 [==============================] - 41s 216ms/step - loss: 0.1742 - accuracy: 0.9422 - val_loss: 0.4714 - val_accuracy: 0.8421
# Epoch 16/80
# 191/191 [==============================] - 47s 246ms/step - loss: 0.1699 - accuracy: 0.9370 - val_loss: 0.6963 - val_accuracy: 0.8316 accuracy: 0.93 - ETA: 17s - loss: 0.1627  - ETA: 13s - loss: 0.1658 - a
# Epoch 17/80
# 191/191 [==============================] - 23s 120ms/step - loss: 0.1662 - accuracy: 0.9440 - val_loss: 0.4657 - val_accuracy: 0.8947
# Epoch 18/80
# 191/191 [==============================] - 21s 110ms/step - loss: 0.1435 - accuracy: 0.9527 - val_loss: 0.4069 - val_accuracy: 0.8566
# Epoch 19/80
# 191/191 [==============================] - 23s 118ms/step - loss: 0.1594 - accuracy: 0.9403 - val_loss: 0.8055 - val_accuracy: 0.8237
# Epoch 20/80
# 191/191 [==============================] - 41s 214ms/step - loss: 0.1760 - accuracy: 0.9335 - val_loss: 0.4917 - val_accuracy: 0.8566
# Epoch 21/80
# 191/191 [==============================] - 46s 240ms/step - loss: 0.1531 - accuracy: 0.9441 - val_loss: 1.1840 - val_accuracy: 0.7855
# Epoch 22/80
# 191/191 [==============================] - 20s 107ms/step - loss: 0.1561 - accuracy: 0.9430 - val_loss: 0.4031 - val_accuracy: 0.8803
# Epoch 23/80
# 191/191 [==============================] - 20s 103ms/step - loss: 0.1304 - accuracy: 0.9483 - val_loss: 0.3668 - val_accuracy: 0.8974
# Epoch 24/80
# 191/191 [==============================] - 20s 105ms/step - loss: 0.1609 - accuracy: 0.9390 - val_loss: 0.5359 - val_accuracy: 0.8566
# Epoch 25/80
# 191/191 [==============================] - 20s 106ms/step - loss: 0.1533 - accuracy: 0.9412 - val_loss: 0.7557 - val_accuracy: 0.8447
# Epoch 26/80
# 191/191 [==============================] - 17s 91ms/step - loss: 0.1617 - accuracy: 0.9501 - val_loss: 0.4730 - val_accuracy: 0.8763
# Epoch 27/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.1285 - accuracy: 0.9538 - val_loss: 0.4493 - val_accuracy: 0.8895
# Epoch 28/80
# 191/191 [==============================] - 17s 88ms/step - loss: 0.1069 - accuracy: 0.9636 - val_loss: 0.5675 - val_accuracy: 0.8618
# Epoch 29/80
# 191/191 [==============================] - 19s 98ms/step - loss: 0.1059 - accuracy: 0.9638 - val_loss: 0.9657 - val_accuracy: 0.8408
# Epoch 30/80
# 191/191 [==============================] - 20s 108ms/step - loss: 0.1395 - accuracy: 0.9471 - val_loss: 0.6366 - val_accuracy: 0.8829
# Epoch 31/80
# 191/191 [==============================] - 18s 95ms/step - loss: 0.1378 - accuracy: 0.9497 - val_loss: 0.5675 - val_accuracy: 0.8855
# Epoch 32/80
# 191/191 [==============================] - 17s 88ms/step - loss: 0.1094 - accuracy: 0.9594 - val_loss: 0.3150 - val_accuracy: 0.9132
# Epoch 33/80
# 191/191 [==============================] - 18s 97ms/step - loss: 0.1217 - accuracy: 0.9580 - val_loss: 0.3153 - val_accuracy: 0.9132
# Epoch 34/80
# 191/191 [==============================] - 17s 91ms/step - loss: 0.1037 - accuracy: 0.9594 - val_loss: 1.0031 - val_accuracy: 0.8329
# Epoch 35/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.1136 - accuracy: 0.9571 - val_loss: 0.3638 - val_accuracy: 0.8908
# Epoch 36/80
# 191/191 [==============================] - 18s 94ms/step - loss: 0.1002 - accuracy: 0.9644 - val_loss: 0.4083 - val_accuracy: 0.8934
# Epoch 37/80
# 191/191 [==============================] - 17s 88ms/step - loss: 0.1081 - accuracy: 0.9600 - val_loss: 0.3674 - val_accuracy: 0.9079
# Epoch 38/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.1224 - accuracy: 0.9499 - val_loss: 0.4028 - val_accuracy: 0.8947
# Epoch 39/80
# 191/191 [==============================] - 15s 81ms/step - loss: 0.1154 - accuracy: 0.9578 - val_loss: 0.5136 - val_accuracy: 0.8855
# Epoch 40/80
# 191/191 [==============================] - 18s 94ms/step - loss: 0.0823 - accuracy: 0.9666 - val_loss: 0.8858 - val_accuracy: 0.8289
# Epoch 41/80
# 191/191 [==============================] - 46s 239ms/step - loss: 0.0928 - accuracy: 0.9619 - val_loss: 1.0763 - val_accuracy: 0.8289
# Epoch 42/80
# 191/191 [==============================] - 38s 199ms/step - loss: 0.0853 - accuracy: 0.9700 - val_loss: 0.9078 - val_accuracy: 0.8237060 - accuracy - ETA: 11s - loss: 0.0832 - a - ETA: 9s - loss: - ETA: 6s - - ETA: 2s - l
# Epoch 43/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.1153 - accuracy: 0.9609 - val_loss: 0.8511 - val_accuracy: 0.8526
# Epoch 44/80
# 191/191 [==============================] - 17s 91ms/step - loss: 0.1287 - accuracy: 0.9548 - val_loss: 0.2163 - val_accuracy: 0.9395
# Epoch 45/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0901 - accuracy: 0.9694 - val_loss: 0.5632 - val_accuracy: 0.8724
# Epoch 46/80
# 191/191 [==============================] - 18s 96ms/step - loss: 0.1183 - accuracy: 0.9612 - val_loss: 0.2479 - val_accuracy: 0.9303
# Epoch 47/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0878 - accuracy: 0.9697 - val_loss: 0.4392 - val_accuracy: 0.9013
# Epoch 48/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0891 - accuracy: 0.9684 - val_loss: 0.2366 - val_accuracy: 0.9250
# Epoch 49/80
# 191/191 [==============================] - 17s 91ms/step - loss: 0.0901 - accuracy: 0.9646 - val_loss: 0.3676 - val_accuracy: 0.9118
# Epoch 50/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0690 - accuracy: 0.9751 - val_loss: 0.3901 - val_accuracy: 0.9026
# Epoch 51/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0847 - accuracy: 0.9646 - val_loss: 0.5746 - val_accuracy: 0.8961
# Epoch 52/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0844 - accuracy: 0.9679 - val_loss: 1.0555 - val_accuracy: 0.8276
# Epoch 53/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0874 - accuracy: 0.9681 - val_loss: 0.1828 - val_accuracy: 0.9566
# Epoch 54/80
# 191/191 [==============================] - 17s 91ms/step - loss: 0.0958 - accuracy: 0.9626 - val_loss: 0.2068 - val_accuracy: 0.9500
# Epoch 55/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0779 - accuracy: 0.9679 - val_loss: 0.3308 - val_accuracy: 0.9158
# Epoch 56/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0700 - accuracy: 0.9742 - val_loss: 0.1575 - val_accuracy: 0.9539
# Epoch 57/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0761 - accuracy: 0.9753 - val_loss: 1.2345 - val_accuracy: 0.8461
# Epoch 58/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.1014 - accuracy: 0.9714 - val_loss: 0.2978 - val_accuracy: 0.9303
# Epoch 59/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.1147 - accuracy: 0.9607 - val_loss: 0.2254 - val_accuracy: 0.9237
# Epoch 60/80
# 191/191 [==============================] - 18s 93ms/step - loss: 0.0601 - accuracy: 0.9774 - val_loss: 0.3939 - val_accuracy: 0.9171
# Epoch 61/80
# 191/191 [==============================] - 18s 93ms/step - loss: 0.0849 - accuracy: 0.9674 - val_loss: 0.3465 - val_accuracy: 0.9132
# Epoch 62/80
# 191/191 [==============================] - 18s 93ms/step - loss: 0.0811 - accuracy: 0.9713 - val_loss: 0.3884 - val_accuracy: 0.9079
# Epoch 63/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0884 - accuracy: 0.9709 - val_loss: 0.3643 - val_accuracy: 0.9171
# Epoch 64/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0726 - accuracy: 0.9748 - val_loss: 0.2331 - val_accuracy: 0.9461
# Epoch 65/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0652 - accuracy: 0.9780 - val_loss: 0.3086 - val_accuracy: 0.9250
# Epoch 66/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0879 - accuracy: 0.9733 - val_loss: 0.7063 - val_accuracy: 0.8842
# Epoch 67/80
# 191/191 [==============================] - 17s 89ms/step - loss: 0.0802 - accuracy: 0.9729 - val_loss: 0.5630 - val_accuracy: 0.9013
# Epoch 68/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0657 - accuracy: 0.9767 - val_loss: 0.2719 - val_accuracy: 0.9224
# Epoch 69/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0650 - accuracy: 0.9775 - val_loss: 0.3814 - val_accuracy: 0.9092
# Epoch 70/80
# 191/191 [==============================] - 19s 101ms/step - loss: 0.0820 - accuracy: 0.9735 - val_loss: 0.3970 - val_accuracy: 0.9224
# Epoch 71/80
# 191/191 [==============================] - 19s 101ms/step - loss: 0.0401 - accuracy: 0.9886 - val_loss: 0.2288 - val_accuracy: 0.9526
# Epoch 72/80
# 191/191 [==============================] - 21s 110ms/step - loss: 0.0828 - accuracy: 0.9657 - val_loss: 0.2807 - val_accuracy: 0.9263
# Epoch 73/80
# 191/191 [==============================] - 20s 105ms/step - loss: 0.0872 - accuracy: 0.9727 - val_loss: 0.3759 - val_accuracy: 0.9250
# Epoch 74/80
# 191/191 [==============================] - 19s 101ms/step - loss: 0.0713 - accuracy: 0.9729 - val_loss: 0.5913 - val_accuracy: 0.8895
# Epoch 75/80
# 191/191 [==============================] - 19s 98ms/step - loss: 0.0609 - accuracy: 0.9774 - val_loss: 0.4671 - val_accuracy: 0.9263
# Epoch 76/80
# 191/191 [==============================] - 19s 100ms/step - loss: 0.0719 - accuracy: 0.9753 - val_loss: 0.4769 - val_accuracy: 0.9145
# Epoch 77/80
# 191/191 [==============================] - 18s 95ms/step - loss: 0.0475 - accuracy: 0.9814 - val_loss: 0.4186 - val_accuracy: 0.9237
# Epoch 78/80
# 191/191 [==============================] - 18s 95ms/step - loss: 0.0464 - accuracy: 0.9858 - val_loss: 0.3728 - val_accuracy: 0.9237
# Epoch 79/80
# 191/191 [==============================] - 18s 93ms/step - loss: 0.0610 - accuracy: 0.9770 - val_loss: 0.3262 - val_accuracy: 0.9184
# Epoch 80/80
# 191/191 [==============================] - 17s 90ms/step - loss: 0.0526 - accuracy: 0.9772 - val_loss: 0.4617 - val_accuracy: 0.9250

# %% [markdown]
# ##Saving Model stuff

# %%
#model.save('Saved models/20epochmay22.h5')

# %% [markdown]
# ## Visualize training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Read from web camera

# %%
cap = cv2.VideoCapture(0) # video capture source camera
time.sleep(1)
ret,frame = cap.read() # return a single frame in variable `frame`
#y=150
#x=200
#h=200
#w=200
y=0
x=0
h=480
w=480
crop = frame[y:y+h, x:x+w]
cv2.imwrite('CLASSIFY/camera.png',crop)
#cv2.imwrite('CLASSIFY/camera.png', frame)
cap.release()
time.sleep(1)
#test_image = cv2.imread('trick.png')
#test_image = cv2.resize(test_image, (64, 64))
#test_image = (test_image[...,::-1].astype(np.float32)) / 255.0

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Here we'll load an image that was not included in the original training or validation data.

# %%
classify_image = "C:/Users/MLSE IT HELPDESK/Desktop/OMARADEV/AI/CLASSIFY/camera.png"
#classify_image = "C:/Users/MLSE IT HELPDESK/Desktop/OMARADEV/AI/CLASSIFY/test-07.jpg"

img = keras.preprocessing.image.load_img(
    classify_image, target_size=(img_height, img_width)
)

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.pSredict(img_array)
score = tf.nn.softmax(predictions[0])

img_array = []
plt.imshow(img)

results = "This image most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score))
print(
    results
)
# Out:
# This image most likely belongs to SCREW with a 96.56 percent confidence.

# %% [markdown]
# ## load the robot

# %%
## ssh(putty) into e3dev brick run -> /usr/bin/rpyc_classic.py --host 169.254.29.3

## don't forget to update this ip too.
##### import ev3dev2 on the remote ev3dev device
ev3dev2_motor = conn.modules['ev3dev2.motor']   #motors
ev3dev2_sensor = conn.modules['ev3dev2.sensor'] #sensors
ev3dev2_sensor_lego = conn.modules['ev3dev2.sensor.lego']    #sensor
ev3dev2_sound = conn.modules['ev3dev2.sound']  # sound

# Load inputs and outputs
spinner = ev3dev2_motor.LargeMotor(ev3dev2_motor.OUTPUT_D)
tilter = ev3dev2_motor.MediumMotor(ev3dev2_motor.OUTPUT_A)
ts = ev3dev2_sensor_lego.TouchSensor(ev3dev2_sensor.INPUT_1)
sound = ev3dev2_sound.Sound()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-14d340dfc29f> in <module>
#       3 ## don't forget to update this ip too.
#       4 ##### import ev3dev2 on the remote ev3dev device
# ----> 5 ev3dev2_motor = conn.modules['ev3dev2.motor']   #motors
#       6 ev3dev2_sensor = conn.modules['ev3dev2.sensor'] #sensors
#       7 ev3dev2_sensor_lego = conn.modules['ev3dev2.sensor.lego']    #sensor
#
# NameError: name 'conn' is not defined

# %%
### sound.speak('Push the button, to scan.')
target = 1
calc = 0
numdirection = 5
change_amount = 0
while True:
    ts.wait_for_pressed()
    sound.speak('scanning')
    cap = cv2.VideoCapture(0) # video capture source camera
    time.sleep(1)
    ret,frame = cap.read() # return a single frame in variable `frame`
    y=0
    x=0
    h=480
    w=480
    crop = frame[y:y+h, x:x+w]
    cv2.imwrite('CLASSIFY/camera.png',crop)
    cap.release()
    time.sleep(1)
    classify_image = "C:/Users/MLSE IT HELPDESK/Desktop/OMARADEV/AI/CLASSIFY/camera.png"

    convert classify image to be able to predict
    img = keras.preprocessing.image.load_img(
        classify_image, target_size=(img_height, img_width)
    )

    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])

    img_array = []
    plt.imshow(img)
    
    results = "This most likely belongs to {} with a {:.2f} percent confidence.".format(class_names[np.argmax(score)], 100 * np.max(score))
    sound.speak(results) 
    
    if (class_names[np.argmax(score)]) == 'RESISTOR':
        target = 1
    
    elif (class_names[np.argmax(score)]) == 'POTENTIOMETER':
        target = 2

    elif (class_names[np.argmax(score)]) == 'SCREW':
        target = 3
    
    elif (class_names[np.argmax(score)]) == 'IC':
        target = 4
        
    elif (class_names[np.argmax(score)]) == 'CAPACITOR':
        target = 5
    
    else:
        target = 6
     
    sound.speak(target)
    change_amount = target - numdirection
    calc = change_amount * 60
    numdirection = numdirection + change_amount
    spinner.on_for_degrees(10, calc, True, True)     #speed, degrees, brake=True, block=True
    tilter.on_for_degrees(10, 45, True, True)
    tilter.on_for_degrees(10, -45, True, True)
